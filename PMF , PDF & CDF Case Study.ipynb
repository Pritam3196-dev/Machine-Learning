# %% [markdown]
# ### PMF , PDF and CDF Case Study

# %%
import pandas as pd

# %%
import random

# %%
L =[]
for i in range(10000):
    
    a = random.randint(1,6)
    b = random.randint(1,6)
    L.append(a+b)

# %%
L
# Out:
# [8,
#  7,
#  6,
#  2,
#  11,
#  6,
#  10,
#  11,
#  5,
#  8,
#  5,
#  4,
#  9,
#  5,
#  6,
#  4,
#  5,
#  9,
#  6,
#  8,
#  5,
#  10,
#  7,
#  7,
#  7,
#  8,
#  4,
#  7,
#  11,
#  2,
#  7,
#  8,
#  6,
#  7,
#  5,
#  5,
#  7,
#  10,
#  9,
#  11,
#  7,
#  12,
#  9,
#  6,
#  5,
#  8,
#  8,
#  7,
#  7,
#  7,
#  5,
#  10,
#  6,
#  11,
#  6,
#  6,
#  5,
#  7,
#  11,
#  4,
#  6,
#  4,
#  4,
#  5,
#  4,
#  7,
#  6,
#  9,
#  9,
#  6,
#  7,
#  4,
#  9,
#  6,
#  10,
#  9,
#  8,
#  10,
#  9,
#  5,
#  10,
#  4,
#  6,
#  8,
#  4,
#  3,
#  6,
#  5,
#  6,
#  5,
#  8,
#  8,
#  8,
#  3,
#  8,
#  7,
#  3,
#  4,
#  4,
#  4,
#  6,
#  8,
#  6,
#  5,
#  7,
#  7,
#  3,
#  3,
#  11,
#  7,
#  3,
#  8,
#  11,
#  11,
#  6,
#  5,
#  6,
#  3,
#  6,
#  4,
#  7,
#  5,
#  5,
#  8,
#  9,
#  4,
#  8,
#  9,
#  11,
#  5,
#  10,
#  10,
#  4,
#  4,
#  10,
#  3,
#  4,
#  9,
#  7,
#  5,
#  6,
#  7,
#  8,
#  10,
#  9,
#  8,
#  9,
#  11,
#  7,
#  8,
#  4,
#  6,
#  5,
#  8,
#  8,
#  7,
#  6,
#  4,
#  7,
#  7,
#  4,
#  9,
# ...

# %%
len(L)
# Out:
# 10000

# %%
s = pd.Series(L).value_counts()

# %%
s
# Out:
# 7     1641
# 8     1438
# 6     1363
# 9     1128
# 5     1100
# 4      853
# 10     804
# 11     583
# 3      523
# 12     288
# 2      279
# dtype: int64

# %%
s = (pd.Series(L).value_counts() / pd.Series(L).value_counts().sum()).sort_index()

# %%
s
# Out:
# 2     0.0279
# 3     0.0523
# 4     0.0853
# 5     0.1100
# 6     0.1363
# 7     0.1641
# 8     0.1438
# 9     0.1128
# 10    0.0804
# 11    0.0583
# 12    0.0288
# dtype: float64

# %%
pd.Series(L).value_counts()
# Out:
# 7     1641
# 8     1438
# 6     1363
# 9     1128
# 5     1100
# 4      853
# 10     804
# 11     583
# 3      523
# 12     288
# 2      279
# dtype: int64

# %%
s.plot(kind = 'bar')
# Out:
# <Axes: >

# %%
import numpy as np
np.cumsum(s).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
# PDF - Parametric Density Estimation (normally distribution)

# %%
import matplotlib.pyplot as plt
from numpy.random import normal

# %%
sample = normal(loc = 50 , scale = 5 , size = 1000)

# %%
sample
# Out:
# array([53.00277659, 46.73259777, 51.39403965, 38.95879538, 51.03902083,
#        51.62963677, 54.94017203, 56.85475294, 50.69202442, 53.89024015,
#        51.62290489, 41.41023627, 50.82643258, 49.63451337, 48.70574691,
#        46.81944138, 52.83173876, 42.57759888, 47.87489699, 51.29974962,
#        52.86968061, 47.08686727, 59.16263176, 53.79995451, 49.90221497,
#        47.75327221, 48.77210978, 55.58302657, 49.277194  , 47.4394293 ,
#        49.55505925, 45.09188681, 61.99416885, 35.96505832, 57.51256168,
#        44.90753455, 49.34317817, 45.83651035, 49.65304453, 55.29280193,
#        52.36159747, 45.34453424, 47.26233328, 55.93980107, 45.45066943,
#        53.87157161, 49.45333557, 49.42986403, 55.70465947, 48.0506792 ,
#        47.66627187, 55.63826827, 48.36067661, 50.79264847, 49.53503505,
#        47.087089  , 47.62679196, 37.81687805, 41.04051467, 58.70395159,
#        57.23444012, 44.9487735 , 46.8646233 , 46.47322996, 49.00502592,
# ...

# %%
#### When u get dataset first calculate mean and std

# %%
sample.mean()
# Out:
# 49.99740218866681

# %%
sample.std()
# Out:
# 5.007497250223964

# %%
plt.hist(sample , bins = 10)
# Out:
# (array([ 11.,  27.,  91., 227., 292., 203., 115.,  28.,   4.,   2.]),
#  array([33.96193363, 37.51171701, 41.0615004 , 44.61128378, 48.16106716,
#         51.71085055, 55.26063393, 58.81041731, 62.3602007 , 65.90998408,
#         69.45976746]),
#  <BarContainer object of 10 artists>)

# %%
#import seaborn as sns
#sns.kdeplot(sample)

# %%
sample.max()
# Out:
# 69.45976746313545

# %%
sample.min()
# Out:
# 33.961933628459235

# %% [markdown]
# # This function is calculate proba. density func

# %%
from scipy.stats import norm
dist = norm(49.99,5.00)

# %%
dist

# %%
values = np.linspace(sample.min() , sample.max() , 100)

# %%
values
# Out:
# array([33.96193363, 34.32049761, 34.67906158, 35.03762556, 35.39618954,
#        35.75475352, 36.1133175 , 36.47188148, 36.83044545, 37.18900943,
#        37.54757341, 37.90613739, 38.26470137, 38.62326534, 38.98182932,
#        39.3403933 , 39.69895728, 40.05752126, 40.41608523, 40.77464921,
#        41.13321319, 41.49177717, 41.85034115, 42.20890513, 42.5674691 ,
#        42.92603308, 43.28459706, 43.64316104, 44.00172502, 44.36028899,
#        44.71885297, 45.07741695, 45.43598093, 45.79454491, 46.15310888,
#        46.51167286, 46.87023684, 47.22880082, 47.5873648 , 47.94592878,
#        48.30449275, 48.66305673, 49.02162071, 49.38018469, 49.73874867,
#        50.09731264, 50.45587662, 50.8144406 , 51.17300458, 51.53156856,
#        51.89013253, 52.24869651, 52.60726049, 52.96582447, 53.32438845,
#        53.68295243, 54.0415164 , 54.40008038, 54.75864436, 55.11720834,
#        55.47577232, 55.83433629, 56.19290027, 56.55146425, 56.91002823,
# ...

# %%
proba = [ dist.pdf(value) for value in values]

# %%
proba
# Out:
# [0.00046832190005846033,
#  0.0005878477625698007,
#  0.0007340942373933818,
#  0.0009120219758828503,
#  0.0011272632122852674,
#  0.0013861553587047838,
#  0.0016957624923721638,
#  0.00206388115169155,
#  0.0024990266500671803,
#  0.0030103960335203612,
#  0.0036078038818923254,
#  0.004301587414621911,
#  0.005102477837389699,
#  0.006021435575611746,
#  0.007069447996135679,
#  0.008257289419331189,
#  0.009595244656162336,
#  0.011092798939414155,
#  0.012758298909197533,
#  0.014598591197759062,
#  0.01661864705945645,
#  0.018821183317031802,
#  0.021206291543475725,
#  0.023771088762768126,
#  0.026509403925694796,
#  0.02941151489839718,
#  0.03246395060437089,
#  0.03564937221867466,
#  0.038946545886330314,
#  0.042330417317772664,
#  0.04577229583158916,
#  0.04924015203604083,
#  0.05269902947175242,
#  0.05611156632016562,
#  0.05943861888828396,
#  0.0626399742056524,
#  0.06567513492386136,
#  0.06850415600420731,
#  0.07108850961798822,
#  0.07339195244699873,
# ...

# %%
plt.hist(sample , bins = 10 , density = True)
plt.plot(values , proba )

# %%
sns.distplot(sample)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_4240\1950040031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>

# %% [markdown]
# # KDE

# %%
sample1 = normal(loc = 20  , scale = 5, size = 300)
sample2 = normal(loc = 40 , scale = 5 , size = 700)

# %%
sample1
# Out:
# array([13.28696294, 14.65957212, 23.93954482, 20.02792754, 25.93188328,
#        27.29564278, 20.07870489, 26.10432275, 30.03507128, 15.37471531,
#        21.8235246 , 22.99301168, 17.65404364, 14.49618044, 18.93910627,
#        16.89696967, 17.57951964, 21.66302967, 23.12820843, 24.78540508,
#        18.60333446, 18.38806076, 23.4460739 , 20.47611893, 26.96159027,
#         3.75570318, 13.46088166, 18.07515185, 13.2408673 , 24.224128  ,
#         9.30102824, 21.0725645 , 22.49048648, 21.79159217, 17.56889138,
#        22.24737887, 16.97481788, 16.02427276, 10.33902826, 25.71264171,
#        12.08913815, 15.04769316, 22.90622467, 14.40532461, 18.00786571,
#        15.13265983, 23.22212396, 16.28762389, 14.33532611, 25.94761277,
#        24.10234478, 29.54759024, 24.03055692, 12.49874528, 27.14239851,
#        15.93662696, 25.25374729, 15.54486132, 32.45398022, 20.59512271,
#        21.20193196, 19.34077518, 22.24169913, 18.54301179, 12.08155624,
# ...

# %%
sample2
# Out:
# array([40.58521481, 38.53239728, 46.66379972, 42.03485535, 40.35090419,
#        30.31174633, 43.40554146, 46.9791538 , 42.6648482 , 35.18623858,
#        39.98753909, 40.46418711, 43.4345528 , 41.96195201, 42.37179351,
#        43.72397238, 44.94750208, 39.36290682, 42.47340854, 39.63096082,
#        40.90109832, 37.2514819 , 48.09366571, 42.5126427 , 41.44321459,
#        40.76163925, 40.19570477, 40.9117067 , 39.54106521, 35.05835085,
#        36.43017161, 39.3966988 , 42.69307601, 38.69909513, 43.55294467,
#        38.55256535, 36.48956235, 44.65705959, 46.11719274, 41.64418278,
#        43.7917873 , 44.08188583, 46.7690082 , 29.4029016 , 40.17857403,
#        41.84029375, 31.35345149, 33.63754595, 39.43261037, 37.78412285,
#        40.14963982, 39.40763692, 37.2015404 , 45.71002394, 45.15714018,
#        49.81337649, 42.97548475, 43.30774201, 32.12686894, 43.54889173,
#        46.90023938, 42.82427071, 46.31720985, 47.73026169, 50.40429779,
# ...

# %%
sample = np.hstack((sample1 , sample2))

# %%
sample
# Out:
# array([13.28696294, 14.65957212, 23.93954482, 20.02792754, 25.93188328,
#        27.29564278, 20.07870489, 26.10432275, 30.03507128, 15.37471531,
#        21.8235246 , 22.99301168, 17.65404364, 14.49618044, 18.93910627,
#        16.89696967, 17.57951964, 21.66302967, 23.12820843, 24.78540508,
#        18.60333446, 18.38806076, 23.4460739 , 20.47611893, 26.96159027,
#         3.75570318, 13.46088166, 18.07515185, 13.2408673 , 24.224128  ,
#         9.30102824, 21.0725645 , 22.49048648, 21.79159217, 17.56889138,
#        22.24737887, 16.97481788, 16.02427276, 10.33902826, 25.71264171,
#        12.08913815, 15.04769316, 22.90622467, 14.40532461, 18.00786571,
#        15.13265983, 23.22212396, 16.28762389, 14.33532611, 25.94761277,
#        24.10234478, 29.54759024, 24.03055692, 12.49874528, 27.14239851,
#        15.93662696, 25.25374729, 15.54486132, 32.45398022, 20.59512271,
#        21.20193196, 19.34077518, 22.24169913, 18.54301179, 12.08155624,
# ...

# %%
plt.hist(sample , bins = 50)
plt.show()

# %%
from sklearn.neighbors import KernelDensity

# %%
model = KernelDensity(bandwidth =  5 , kernel = 'gaussian')

# %%
model
# Out:
# KernelDensity(bandwidth=5)

# %%
sample.shape
# Out:
# (1000,)

# %%
len(sample)
# Out:
# 1000

# %%
sample = sample.reshape(len(sample) , 1)

# %%
sample
# Out:
# array([[13.28696294],
#        [14.65957212],
#        [23.93954482],
#        [20.02792754],
#        [25.93188328],
#        [27.29564278],
#        [20.07870489],
#        [26.10432275],
#        [30.03507128],
#        [15.37471531],
#        [21.8235246 ],
#        [22.99301168],
#        [17.65404364],
#        [14.49618044],
#        [18.93910627],
#        [16.89696967],
#        [17.57951964],
#        [21.66302967],
#        [23.12820843],
#        [24.78540508],
#        [18.60333446],
#        [18.38806076],
#        [23.4460739 ],
#        [20.47611893],
#        [26.96159027],
#        [ 3.75570318],
#        [13.46088166],
#        [18.07515185],
#        [13.2408673 ],
#        [24.224128  ],
#        [ 9.30102824],
#        [21.0725645 ],
#        [22.49048648],
#        [21.79159217],
#        [17.56889138],
#        [22.24737887],
#        [16.97481788],
#        [16.02427276],
#        [10.33902826],
#        [25.71264171],
#        [12.08913815],
# ...

# %%
sample.shape
# Out:
# (1000, 1)

# %%
model.fit(sample)
# Out:
# KernelDensity(bandwidth=5)

# %%
values = np.linspace(sample.min() , sample.max() , 100)

# %%
values.shape
# Out:
# (100,)

# %%
values = values.reshape(len(values) , 1)

# %%
values.shape
# Out:
# (100, 1)

# %%
prob = model.score_samples(values)

# %%
prob
# Out:
# array([-6.58827866, -6.43630046, -6.2881708 , -6.14394192, -6.00368977,
#        -5.86750902, -5.73550815, -5.60780457, -5.48452034, -5.36577834,
#        -5.2516991 , -5.14239832, -5.037985  , -4.9385601 , -4.84421573,
#        -4.75503471, -4.67109033, -4.59244629, -4.51915667, -4.4512658 ,
#        -4.38880795, -4.33180677, -4.28027432, -4.23420972, -4.19359726,
#        -4.15840386, -4.12857588, -4.10403519, -4.08467425, -4.07035037,
#        -4.06087886, -4.05602506, -4.0554955 , -4.05892795, -4.06588115,
#        -4.07582441, -4.08812852, -4.10205906, -4.11677457, -4.13133179,
#        -4.14470108, -4.15579443, -4.16350777, -4.16677706, -4.16464462,
#        -4.15632893, -4.14128828, -4.11926776, -4.09032098, -4.05480244,
#        -4.01333215, -3.96673936, -3.91599555, -3.86214667, -3.80625302,
#        -3.74934161, -3.69237254, -3.63621879, -3.58165698, -3.52936637,
#        -3.47993335, -3.43385918, -3.39156924, -3.35342264, -3.31972135,
# ...

# %%
prob = np.exp(prob)

# %%
prob
# Out:
# array([0.00137641, 0.00160232, 0.00185816, 0.00214645, 0.00246962,
#        0.00282991, 0.00322924, 0.00366912, 0.00415053, 0.00467382,
#        0.00523861, 0.00584366, 0.00648681, 0.00716491, 0.00787379,
#        0.00860825, 0.00936206, 0.01012805, 0.01089821, 0.01166379,
#        0.01241552, 0.01314378, 0.01383887, 0.01449126, 0.0150919 ,
#        0.01563249, 0.0161058 , 0.01650594, 0.01682862, 0.01707141,
#        0.01723387, 0.01731772, 0.01732689, 0.01726752, 0.01714787,
#        0.01697821, 0.01677059, 0.01653859, 0.01629699, 0.01606147,
#        0.01584817, 0.01567333, 0.01555291, 0.01550214, 0.01553523,
#        0.01566496, 0.01590235, 0.01625641, 0.01673386, 0.01733891,
#        0.01807307, 0.01893507, 0.01992071, 0.02102282, 0.02223132,
#        0.02353323, 0.02491283, 0.0263518 , 0.02782955, 0.02932349,
#        0.03080946, 0.03226219, 0.03365582, 0.03496448, 0.03616291,
#        0.03722709, 0.03813487, 0.03886656, 0.03940551, 0.03973856,
# ...

# %%
plt.hist(sample , bins = 50 , density = True)
plt.plot(values[:] , prob)

# %%
sns.kdeplot(sample.reshape(1000) , bw_adjust = 2)
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data = df , x = 'sepal_length' , hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'sepal_width' , hue = 'species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data = df , x = 'petal_length' , hue = 'species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>
